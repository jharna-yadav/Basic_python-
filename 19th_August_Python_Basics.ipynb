# %% [markdown]
# 1. Declare two variables, `x` and `y`, and assign them integer values.
#  Swap the values of these variables without using any temporary
# variable.

# %%
x=10
y=20
x=x+y
y=x-y
x=x-y
print("This is my new x:" ,x)
print("this is my new y:",y)
# Out:
# This is my new x: 20
# this is my new y: 10

# %% [markdown]
#  2. Create a program that calculates the area of a rectangle. Take the
#  length and width as inputs from the user and store them in variables.
#  Calculate and display the area.

# %%
length=int(input("Enter the Length of rectangle : "))
width=int(input("Enter the width of the rectange: "))
area=length*width
print("The area of rectangle is:",area,"units.")
# Out:
# enter the Length of rectangle : 20
# Enter the width of the rectange: 30
# The area of rectangle is: 600 units.

# %% [markdown]
#  3. Write a Python program that converts temperature from Celsius to
#  Fahrenheit. Take the temperature in Celsius as input, store it in a
#  variable, convert it to Fahrenheit, and display the result.

# %%
Temp=int(input("Enter the temp : "))
Temperature =9/8*Temp+32
print("The temerature in Fahrenheit =",Temperature,"F")
# Out:
# Enter the temp : 34
# The temerature in Fahrenheit = 70.25 F

# %% [markdown]
# ### Strings

# %% [markdown]
# 1. Write a Python program that takes a string as input and prints the length of
# the string.

# %%
string =input("Enter your string here: ")
print("The length of string is :",len(string))
# Out:
# Enter your string here: Hello everybody
# The length of string is : 15

# %% [markdown]
# 2. Create a program that takes a sentence from the user and counts the number
# of vowels (a, e, i, o, u) in the string.

# %%
Sentence = input("Enter your sentence here : ")
sent=Sentence.upper()
cnt=0
for vowel in "AEIOU":
  x=sent.count(vowel)
  cnt=cnt+x
print("Number of vowels in sentence :",cnt)
# Out:
# Enter your sentence here : To thrive and survive in this world we need a higher purpose
# Number of vowels in sentence : 19

# %% [markdown]
# 3. Given a string, reverse the order of characters using string slicing and print
# the reversed string.

# %%
String = "Python is a dynamically typed language."
String[::-1]
# Out:
# '.egaugnal depyt yllacimanyd a si nohtyP'

# %% [markdown]
# 4. Write a program that takes a string as input and checks if it is a palindrome
# (reads the same forwards and backwards).

# %%
Text=input("Enter your string here : ")
if Text==Text[::-1]:
  print(f"{Text}  is a palindrome")
else:
  print(f"{Text}Not a palindrome.")
# Out:
# Enter your string here : madam
# madam  is a palindrome

# %% [markdown]
# 5.Create a program that takes a string as input and removes all the spaces from
# it. Print the modified string without spaces.

# %%
Para=input("Enter your string here: ")
for p in Para.split():
  print(p,end="")
# Out:
# Enter your string here: Python is easy to learn.
# Pythoniseasytolearn.

# %%
#Or
para=input("Enter your string here: ")
para.replace(" ","")
# Out:
# Enter your string here: hey, it is good to see you again
# 'hey,itisgoodtoseeyouagain'
